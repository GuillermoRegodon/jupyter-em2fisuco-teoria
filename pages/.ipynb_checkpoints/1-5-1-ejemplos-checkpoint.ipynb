# %% [markdown]
# # Ejemplos

# %% [markdown]
# ## Ejemplo de onda electromagnética atenuada
#
# Esta animación se encuentra en la siguiente URL:
#
# %%html
# <a href="https://github.com/GuillermoRegodon/matlab-em2fisuco-examples/blob/main/EMwave_alpha_Animated.m">Onda atenuada configurable</a>
#
# Ejemplos de plots, ejecutar en Matlab:
# * EMwave_alpha_Animated
# * EMwave_alpha_Animated('lambda', 2)
# * EMwave_alpha_Animated('alpha', 1)
# * EMwave_alpha_Animated('alpha', 10)
# * EMwave_alpha_Animated('alpha', 1, 'visually_reduce_alpha', 1)

# %% [markdown]
# ## Ejemplo de interfaz
#
# Esta animación se encuentra en la siguiente URL:
#
# %%html
# <a href="https://github.com/GuillermoRegodon/matlab-em2fisuco-examples/blob/main/EMInterfaceApp.m">Interfaz con ondas incidente, reflejada y transmitida</a>
#
# Ejecutar en Matlab:
#
# * EMInterfaceApp
#
# Comprobar como la única combinación que permite cumplir las dos condiciones de contorno (*Continuidad de E y H*) es la que da la teoría.
